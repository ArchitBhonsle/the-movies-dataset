# %%
import pandas as pd
import numpy as np
from pprint import pprint

pd.options.display.max_columns = None

# %%
from ast import literal_eval

def to_array_of_fields(field):
    def inner(string):
        return tuple(sorted([
            item[field]
            for item in 
            ([] if string == "" else literal_eval(string))
        ]))
    return inner

# %%
credits = pd.read_csv(
    'data/credits.csv',
    dtype={
        'id': 'int64'
    },
    converters={
        'cast': to_array_of_fields('name'),
        'crew': to_array_of_fields('name'),
    }
)
credits
# Out:
#                                                     cast  \
# 0      (Annie Potts, Don Rickles, Erik von Detten, Ji...
# 1      (Adam Hann-Byrd, Annabel Kershaw, Bebe Neuwirt...
# 2      (Ann-Margret, Burgess Meredith, Daryl Hannah, ...
# 3      (Angela Bassett, Dennis Haysbert, Gregory Hine...
# 4      (BD Wong, Diane Keaton, Eugene Levy, George Ne...
# ...                                                  ...
# 45471        (Elham Korda, Kourosh Tahami, Leila Hatami)
# 45472  (Angel Aquino, Angeli Bayani, Bart Guingona, B...
# 45473  (Adam Baldwin, Damian Chapa, Darrell Dubovsky,...
# 45474  (Aleksandr Chabrov, Iwan Mosschuchin, Nathalie...
# 45475                                                 ()
#
#                                                     crew      id
# 0      (Ada Cochavi, Alan Sperling, Alec Sokolow, And...     862
# 1      (Chris van Allsburg, Greg Taylor, James D. Bis...    8844
# 2      (Howard Deutch, Jack Keller, Mark Steven Johns...   15602
# 3      (Caron K, Deborah Schindler, Ezra Swerdlow, Fo...   31357
# 4      (Adam Bernardi, Alan Silvestri, Albert Hackett...   11862
# ...                                                  ...     ...
# 45471  (Azadeh Ghavam, Babak Ardalan, Farshad Mohamma...  439050
# 45472  (Dante Perez, Lav Diaz, Lav Diaz, Lav Diaz, La...  111109
# 45473  (C. Courtney Joyner, Jeffrey Goldenberg, João ...   67758
# 45474            (Joseph N. Ermolieff, Yakov Protazanov)  227506
# 45475                                   (Daisy Asquith,)  461257
#
# [45476 rows x 3 columns]

# %%
credits[credits['crew'] == float('nan')]
# Out:
# Empty DataFrame
# Columns: [cast, crew, id]
# Index: []

# %%
credits_unique = credits.drop_duplicates(subset='id')
credits_unique
# Out:
#                                                     cast  \
# 0      (Annie Potts, Don Rickles, Erik von Detten, Ji...
# 1      (Adam Hann-Byrd, Annabel Kershaw, Bebe Neuwirt...
# 2      (Ann-Margret, Burgess Meredith, Daryl Hannah, ...
# 3      (Angela Bassett, Dennis Haysbert, Gregory Hine...
# 4      (BD Wong, Diane Keaton, Eugene Levy, George Ne...
# ...                                                  ...
# 45471        (Elham Korda, Kourosh Tahami, Leila Hatami)
# 45472  (Angel Aquino, Angeli Bayani, Bart Guingona, B...
# 45473  (Adam Baldwin, Damian Chapa, Darrell Dubovsky,...
# 45474  (Aleksandr Chabrov, Iwan Mosschuchin, Nathalie...
# 45475                                                 ()
#
#                                                     crew      id
# 0      (Ada Cochavi, Alan Sperling, Alec Sokolow, And...     862
# 1      (Chris van Allsburg, Greg Taylor, James D. Bis...    8844
# 2      (Howard Deutch, Jack Keller, Mark Steven Johns...   15602
# 3      (Caron K, Deborah Schindler, Ezra Swerdlow, Fo...   31357
# 4      (Adam Bernardi, Alan Silvestri, Albert Hackett...   11862
# ...                                                  ...     ...
# 45471  (Azadeh Ghavam, Babak Ardalan, Farshad Mohamma...  439050
# 45472  (Dante Perez, Lav Diaz, Lav Diaz, Lav Diaz, La...  111109
# 45473  (C. Courtney Joyner, Jeffrey Goldenberg, João ...   67758
# 45474            (Joseph N. Ermolieff, Yakov Protazanov)  227506
# 45475                                   (Daisy Asquith,)  461257
#
# [45432 rows x 3 columns]

# %%
keywords = pd.read_csv(
    'data/keywords.csv',
    dtype={
        'id': 'int64'
    },
    converters={
        'keywords': to_array_of_fields('name')
    }
)
keywords
# Out:
#            id                                           keywords
# 0         862  (boy, boy next door, friends, friendship, jeal...
# 1        8844  (based on children's book, board game, disappe...
# 2       15602  (best friend, duringcreditsstinger, fishing, o...
# 3       31357  (based on novel, chick flick, divorce, interra...
# 4       11862  (aging, baby, confidence, contraception, daugh...
# ...       ...                                                ...
# 46414  439050                                     (tragic love,)
# 46415  111109                              (artist, pinoy, play)
# 46416   67758                                                 ()
# 46417  227506                                                 ()
# 46418  461257                                                 ()
#
# [46419 rows x 2 columns]

# %%
keywords_unique = keywords.drop_duplicates(subset='id')
keywords_unique
# Out:
#            id                                           keywords
# 0         862  (boy, boy next door, friends, friendship, jeal...
# 1        8844  (based on children's book, board game, disappe...
# 2       15602  (best friend, duringcreditsstinger, fishing, o...
# 3       31357  (based on novel, chick flick, divorce, interra...
# 4       11862  (aging, baby, confidence, contraception, daugh...
# ...       ...                                                ...
# 46414  439050                                     (tragic love,)
# 46415  111109                              (artist, pinoy, play)
# 46416   67758                                                 ()
# 46417  227506                                                 ()
# 46418  461257                                                 ()
#
# [45432 rows x 2 columns]

# %%
movies = pd.read_csv(
    'data/movies_metadata.csv',
    dtype={
        'adult': 'boolean',
        'budget': 'int64',
        'homepage': 'str',
        'id': 'int64',
        'imdb_id': 'str',
        'original_language': 'str',
        'original_title': 'str',
        'overview': 'str',
        'popularity': 'float64',
        'poster_path': 'str',
        'revenue': 'float64',
        'runtime': 'float64',
        'status': 'str',
        'tagline': 'str',
        'title': 'str',
        'video': 'boolean',
        'vote_average': 'float64',
        'vote_count': 'int'
    },
    converters={
        'belongs_to_collection': lambda string: "" if string == "" else literal_eval(string)['name'],
        'genres': to_array_of_fields('name'),
        'production_companies': to_array_of_fields('name'),
        'production_countries': to_array_of_fields('name'),
        'spoken_languages': to_array_of_fields('name'),
    },
    skiprows=[
        19731, 29504, 35588, # strings in 'adult'
        19730, 29503, 35587  # 'NA' in 'vote_count' 
    ],
    parse_dates=['release_date']
)
movies
# Out:
#        adult           belongs_to_collection    budget  \
# 0      False            Toy Story Collection  30000000
# 1      False                                  65000000
# 2      False       Grumpy Old Men Collection         0
# 3      False                                  16000000
# 4      False  Father of the Bride Collection         0
# ...      ...                             ...       ...
# 45455  False                                         0
# 45456  False                                         0
# 45457  False                                         0
# 45458  False                                         0
# 45459  False                                         0
#
#                              genres                              homepage  \
# 0       (Animation, Comedy, Family)  http://toystory.disney.com/toy-story
# 1      (Adventure, Family, Fantasy)                                   NaN
# 2                 (Comedy, Romance)                                   NaN
# 3          (Comedy, Drama, Romance)                                   NaN
# 4                         (Comedy,)                                   NaN
# ...                             ...                                   ...
# 45455               (Drama, Family)  http://www.imdb.com/title/tt6209470/
# 45456                      (Drama,)                                   NaN
# 45457     (Action, Drama, Thriller)                                   NaN
# 45458                            ()                                   NaN
# 45459                            ()                                   NaN
#
#            id    imdb_id original_language               original_title  \
# 0         862  tt0114709                en                    Toy Story
# 1        8844  tt0113497                en                      Jumanji
# 2       15602  tt0113228                en             Grumpier Old Men
# 3       31357  tt0114885                en            Waiting to Exhale
# 4       11862  tt0113041                en  Father of the Bride Part II
# ...       ...        ...               ...                          ...
# 45455  439050  tt6209470                fa                      رگ خواب
# 45456  111109  tt2028550                tl          Siglo ng Pagluluwal
# 45457   67758  tt0303758                en                     Betrayal
# 45458  227506  tt0008536                en          Satana likuyushchiy
# 45459  461257  tt6980792                en                     Queerama
#
#                                                 overview  popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...   21.946943
# 1      When siblings Judy and Peter discover an encha...   17.015539
# 2      A family wedding reignites the ancient feud be...   11.712900
# 3      Cheated on, mistreated and stepped on, the wom...    3.859495
# 4      Just when George Banks has recovered from his ...    8.387519
# ...                                                  ...         ...
# 45455        Rising and falling between a man and woman.    0.072051
# 45456  An artist struggles to finish his work while a...    0.178241
# 45457  When one of her hits goes wrong, a professiona...    0.903007
# 45458  In a small town live two brothers, one a minis...    0.003503
# 45459  50 years after decriminalisation of homosexual...    0.163015
#
#                             poster_path  \
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...                                 ...
# 45455  /jldsYflnId4tTWPx8es3uzsB1I8.jpg
# 45456  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg
# 45457  /d5bX92nDsISNhu3ZT69uHwmfCGw.jpg
# 45458  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg
# 45459  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
#
#                                     production_companies  \
# 0                             (Pixar Animation Studios,)
# 1      (Interscope Communications, Teitler Film, TriS...
# 2                         (Lancaster Gate, Warner Bros.)
# 3              (Twentieth Century Fox Film Corporation,)
# 4           (Sandollar Productions, Touchstone Pictures)
# ...                                                  ...
# 45455                                                 ()
# 45456                                     (Sine Olivia,)
# 45457                         (American World Pictures,)
# 45458                                       (Yermoliev,)
# 45459                                                 ()
#
#               production_countries release_date      revenue  runtime  \
# 0      (United States of America,)   1995-10-30  373554033.0     81.0
# 1      (United States of America,)   1995-12-15  262797249.0    104.0
# 2      (United States of America,)   1995-12-22          0.0    101.0
# 3      (United States of America,)   1995-12-22   81452156.0    127.0
# 4      (United States of America,)   1995-02-10   76578911.0    106.0
# ...                            ...          ...          ...      ...
# 45455                      (Iran,)          NaT          0.0     90.0
# 45456               (Philippines,)   2011-11-17          0.0    360.0
# 45457  (United States of America,)   2003-08-01          0.0     90.0
# 45458                    (Russia,)   1917-10-21          0.0     87.0
# 45459            (United Kingdom,)   2017-06-09          0.0     75.0
#
#           spoken_languages    status  \
# 0               (English,)  Released
# 1      (English, Français)  Released
# 2               (English,)  Released
# 3               (English,)  Released
# 4               (English,)  Released
# ...                    ...       ...
# 45455             (فارسی,)  Released
# 45456                  (,)  Released
# 45457           (English,)  Released
# 45458                   ()  Released
# 45459           (English,)  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45455         Rising and falling between a man and woman
# 45456                                                NaN
# 45457                             A deadly game of wits.
# 45458                                                NaN
# 45459                                                NaN
#
#                              title  video  vote_average  vote_count
# 0                        Toy Story  False           7.7        5415
# 1                          Jumanji  False           6.9        2413
# 2                 Grumpier Old Men  False           6.5          92
# 3                Waiting to Exhale  False           6.1          34
# 4      Father of the Bride Part II  False           5.7         173
# ...                            ...    ...           ...         ...
# 45455                       Subdue  False           4.0           1
# 45456          Century of Birthing  False           9.0           3
# 45457                     Betrayal  False           3.8           6
# 45458             Satan Triumphant  False           0.0           0
# 45459                     Queerama  False           0.0           0
#
# [45460 rows x 24 columns]

# %%
movie_title_to_id = dict()
movie_id_to_original = dict()
for idx, movie in movies.iterrows():
    id, title = movie['id'], movie['title']
    if title not in movie_title_to_id:
        movie_title_to_id[title] = id
    movie_id_to_original[id] = movie_title_to_id[title]

len(movie_title_to_id), len(movie_id_to_original)
# Out:
# (42277, 45430)

# %%
movies_unique = movies.drop_duplicates(subset='title')
movies_unique
# Out:
#        adult           belongs_to_collection    budget  \
# 0      False            Toy Story Collection  30000000
# 1      False                                  65000000
# 2      False       Grumpy Old Men Collection         0
# 3      False                                  16000000
# 4      False  Father of the Bride Collection         0
# ...      ...                             ...       ...
# 45453  False                                         0
# 45455  False                                         0
# 45456  False                                         0
# 45458  False                                         0
# 45459  False                                         0
#
#                              genres                              homepage  \
# 0       (Animation, Comedy, Family)  http://toystory.disney.com/toy-story
# 1      (Adventure, Family, Fantasy)                                   NaN
# 2                 (Comedy, Romance)                                   NaN
# 3          (Comedy, Drama, Romance)                                   NaN
# 4                         (Comedy,)                                   NaN
# ...                             ...                                   ...
# 45453            (Science Fiction,)                                   NaN
# 45455               (Drama, Family)  http://www.imdb.com/title/tt6209470/
# 45456                      (Drama,)                                   NaN
# 45458                            ()                                   NaN
# 45459                            ()                                   NaN
#
#            id    imdb_id original_language               original_title  \
# 0         862  tt0114709                en                    Toy Story
# 1        8844  tt0113497                en                      Jumanji
# 2       15602  tt0113228                en             Grumpier Old Men
# 3       31357  tt0114885                en            Waiting to Exhale
# 4       11862  tt0113041                en  Father of the Bride Part II
# ...       ...        ...               ...                          ...
# 45453  222848  tt0112613                en              Caged Heat 3000
# 45455  439050  tt6209470                fa                      رگ خواب
# 45456  111109  tt2028550                tl          Siglo ng Pagluluwal
# 45458  227506  tt0008536                en          Satana likuyushchiy
# 45459  461257  tt6980792                en                     Queerama
#
#                                                 overview  popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...   21.946943
# 1      When siblings Judy and Peter discover an encha...   17.015539
# 2      A family wedding reignites the ancient feud be...   11.712900
# 3      Cheated on, mistreated and stepped on, the wom...    3.859495
# 4      Just when George Banks has recovered from his ...    8.387519
# ...                                                  ...         ...
# 45453  It's the year 3000 AD. The world's most danger...    0.661558
# 45455        Rising and falling between a man and woman.    0.072051
# 45456  An artist struggles to finish his work while a...    0.178241
# 45458  In a small town live two brothers, one a minis...    0.003503
# 45459  50 years after decriminalisation of homosexual...    0.163015
#
#                             poster_path  \
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...                                 ...
# 45453  /4lF9LH0b0Z1X94xGK9IOzqEW6k1.jpg
# 45455  /jldsYflnId4tTWPx8es3uzsB1I8.jpg
# 45456  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg
# 45458  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg
# 45459  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
#
#                                     production_companies  \
# 0                             (Pixar Animation Studios,)
# 1      (Interscope Communications, Teitler Film, TriS...
# 2                         (Lancaster Gate, Warner Bros.)
# 3              (Twentieth Century Fox Film Corporation,)
# 4           (Sandollar Productions, Touchstone Pictures)
# ...                                                  ...
# 45453                           (Concorde-New Horizons,)
# 45455                                                 ()
# 45456                                     (Sine Olivia,)
# 45458                                       (Yermoliev,)
# 45459                                                 ()
#
#               production_countries release_date      revenue  runtime  \
# 0      (United States of America,)   1995-10-30  373554033.0     81.0
# 1      (United States of America,)   1995-12-15  262797249.0    104.0
# 2      (United States of America,)   1995-12-22          0.0    101.0
# 3      (United States of America,)   1995-12-22   81452156.0    127.0
# 4      (United States of America,)   1995-02-10   76578911.0    106.0
# ...                            ...          ...          ...      ...
# 45453  (United States of America,)   1995-01-01          0.0     85.0
# 45455                      (Iran,)          NaT          0.0     90.0
# 45456               (Philippines,)   2011-11-17          0.0    360.0
# 45458                    (Russia,)   1917-10-21          0.0     87.0
# 45459            (United Kingdom,)   2017-06-09          0.0     75.0
#
#           spoken_languages    status  \
# 0               (English,)  Released
# 1      (English, Français)  Released
# 2               (English,)  Released
# 3               (English,)  Released
# 4               (English,)  Released
# ...                    ...       ...
# 45453           (English,)  Released
# 45455             (فارسی,)  Released
# 45456                  (,)  Released
# 45458                   ()  Released
# 45459           (English,)  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 45453                                                NaN
# 45455         Rising and falling between a man and woman
# 45456                                                NaN
# 45458                                                NaN
# 45459                                                NaN
#
#                              title  video  vote_average  vote_count
# 0                        Toy Story  False           7.7        5415
# 1                          Jumanji  False           6.9        2413
# 2                 Grumpier Old Men  False           6.5          92
# 3                Waiting to Exhale  False           6.1          34
# 4      Father of the Bride Part II  False           5.7         173
# ...                            ...    ...           ...         ...
# 45453              Caged Heat 3000  False           3.5           1
# 45455                       Subdue  False           4.0           1
# 45456          Century of Birthing  False           9.0           3
# 45458             Satan Triumphant  False           0.0           0
# 45459                     Queerama  False           0.0           0
#
# [42277 rows x 24 columns]

# %%
movies[movies['genres'] == ()]
# Out:
#        adult belongs_to_collection  budget genres homepage      id    imdb_id  \
# 55     False                             0     ()      NaN  124057  tt0113541
# 83     False                             0     ()      NaN  188588  tt0113612
# 126    False                             0     ()      NaN  290157  tt0110217
# 137    False                             0     ()      NaN  124639  tt0114618
# 390    False                             0     ()      NaN  267188  tt0112849
# ...      ...                   ...     ...    ...      ...     ...        ...
# 45441  False                             0     ()      NaN   44324  tt0135631
# 45442  False                             0     ()      NaN  122036  tt0224286
# 45449  False                             0     ()      NaN   67179  tt0069215
# 45458  False                             0     ()      NaN  227506  tt0008536
# 45459  False                             0     ()      NaN  461257  tt6980792
#
#       original_language                     original_title  \
# 55                   en            Kids of the Round Table
# 83                   en        Last Summer in the Hamptons
# 126                  en                     Jupiter's Wife
# 137                  en                             Target
# 390                  en                       Desert Winds
# ...                 ...                                ...
# 45441                fr               Le Roi du maquillage
# 45442                fr  Les Transmutations imperceptibles
# 45449                it         San Michele aveva un gallo
# 45458                en                Satana likuyushchiy
# 45459                en                           Queerama
#
#                                                 overview  popularity  \
# 55     Set in modern times, Alex finds King Arthur's ...    0.307075
# 83     Filmed entirely on location in East Hampton, L...    0.531159
# 126    Michel Negroponte, a documentary filmmaker, me...    0.001178
# 137     A subtle yet violent commentary on feudal lords.    0.001205
# 390    Jackie and Eugene are joined by a mystical win...    0.251223
# ...                                                  ...         ...
# 45441  The background of this picture represents a sc...    0.213973
# 45442  This shows a prince entering upon the stage of...    0.071782
# 45449  Sentenced to life imprisonment for illegal act...    0.225051
# 45458  In a small town live two brothers, one a minis...    0.003503
# 45459  50 years after decriminalisation of homosexual...    0.163015
#
#                             poster_path  \
# 55     /tL9ImxOccEshRlgmrKQabKH2tCd.jpg
# 83     /pfgpkDNcwSi1x4jVzeLqvxTwX5a.jpg
# 126    /uUi23HjvDFYGfuVlCBGozUY1Ab4.jpg
# 137    /z0ezqAFMeGYd5mLEWaN8jC9eczF.jpg
# 390    /taQ3WgPtiGT9bVPTlQ4caxFlvUA.jpg
# ...                                 ...
# 45441  /ifWvveLPWWrzitz4oL01YMEokiB.jpg
# 45442  /ifWvveLPWWrzitz4oL01YMEokiB.jpg
# 45449  /j1AN0L4motTt8SBxeTMXDtExsYl.jpg
# 45458  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg
# 45459  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
#
#                          production_companies production_countries  \
# 55     (Melenny Productions, Telefilm Canada)                   ()
# 83                                         ()                   ()
# 126                                        ()                   ()
# 137                                        ()                   ()
# 390                                        ()                   ()
# ...                                       ...                  ...
# 45441                    (Star Film Company,)            (France,)
# 45442                    (Star Film Company,)            (France,)
# 45449                                      ()                   ()
# 45458                            (Yermoliev,)            (Russia,)
# 45459                                      ()    (United Kingdom,)
#
#       release_date  revenue  runtime spoken_languages    status  \
# 55      1997-07-08      0.0     89.0       (English,)  Released
# 83      1995-11-22      0.0    108.0               ()  Released
# 126     1995-01-01      0.0     87.0               ()  Released
# 137     1995-08-01      0.0    122.0               ()  Released
# 390     1997-12-31      0.0     97.0               ()  Released
# ...            ...      ...      ...              ...       ...
# 45441   1904-03-05      0.0      3.0               ()  Released
# 45442   1904-01-01      0.0      2.0               ()  Released
# 45449   1972-01-01      0.0     90.0      (Italiano,)  Released
# 45458   1917-10-21      0.0     87.0               ()  Released
# 45459   2017-06-09      0.0     75.0       (English,)  Released
#
#                             tagline                             title  video  \
# 55                              NaN           Kids of the Round Table  False
# 83                              NaN       Last Summer in the Hamptons  False
# 126    A Haunting Real Life Mystery                    Jupiter's Wife  False
# 137                             NaN                            Target  False
# 390         It began with a whisper                      Desert Winds  False
# ...                             ...                               ...    ...
# 45441                           NaN           The Untameable Whiskers  False
# 45442                           NaN  The Imperceptable Transmutations  False
# 45449                           NaN         St. Michael Had a Rooster  False
# 45458                           NaN                  Satan Triumphant  False
# 45459                           NaN                          Queerama  False
#
#        vote_average  vote_count
# 55              3.0           1
# 83              0.0           0
# 126             0.0           0
# 137             0.0           0
# 390             0.0           0
# ...             ...         ...
# 45441           6.0           6
# 45442           5.0           2
# 45449           6.0           3
# 45458           0.0           0
# 45459           0.0           0
#
# [2442 rows x 24 columns]

# %%
duplicates = 0
for i, m in movies_unique.iterrows():
    id = m['id']
    if id != movie_id_to_original[id]:
        duplicates += 1
print(duplicates)
# Out:
# 0

# %%
credits_unique['id'].count(), movies_unique['id'].count(), keywords_unique['id'].count()
# Out:
# (45432, 42277, 45432)

# %%
not_real = 0
for i, c in keywords_unique.iterrows():
    id = c['id']
    if id not in movie_id_to_original or movie_id_to_original[id] != id:
        not_real += 1

not_real
# Out:
# 3156

# %%
everything = pd.merge(
    left=pd.merge(left=movies_unique, right=credits_unique, on='id', how='left'),
    right=keywords_unique,
    on='id',
    how='inner'
)
everything
# Out:
#        adult           belongs_to_collection    budget  \
# 0      False            Toy Story Collection  30000000
# 1      False                                  65000000
# 2      False       Grumpy Old Men Collection         0
# 3      False                                  16000000
# 4      False  Father of the Bride Collection         0
# ...      ...                             ...       ...
# 42271  False                                         0
# 42272  False                                         0
# 42273  False                                         0
# 42274  False                                         0
# 42275  False                                         0
#
#                              genres                              homepage  \
# 0       (Animation, Comedy, Family)  http://toystory.disney.com/toy-story
# 1      (Adventure, Family, Fantasy)                                   NaN
# 2                 (Comedy, Romance)                                   NaN
# 3          (Comedy, Drama, Romance)                                   NaN
# 4                         (Comedy,)                                   NaN
# ...                             ...                                   ...
# 42271            (Science Fiction,)                                   NaN
# 42272               (Drama, Family)  http://www.imdb.com/title/tt6209470/
# 42273                      (Drama,)                                   NaN
# 42274                            ()                                   NaN
# 42275                            ()                                   NaN
#
#            id    imdb_id original_language               original_title  \
# 0         862  tt0114709                en                    Toy Story
# 1        8844  tt0113497                en                      Jumanji
# 2       15602  tt0113228                en             Grumpier Old Men
# 3       31357  tt0114885                en            Waiting to Exhale
# 4       11862  tt0113041                en  Father of the Bride Part II
# ...       ...        ...               ...                          ...
# 42271  222848  tt0112613                en              Caged Heat 3000
# 42272  439050  tt6209470                fa                      رگ خواب
# 42273  111109  tt2028550                tl          Siglo ng Pagluluwal
# 42274  227506  tt0008536                en          Satana likuyushchiy
# 42275  461257  tt6980792                en                     Queerama
#
#                                                 overview  popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...   21.946943
# 1      When siblings Judy and Peter discover an encha...   17.015539
# 2      A family wedding reignites the ancient feud be...   11.712900
# 3      Cheated on, mistreated and stepped on, the wom...    3.859495
# 4      Just when George Banks has recovered from his ...    8.387519
# ...                                                  ...         ...
# 42271  It's the year 3000 AD. The world's most danger...    0.661558
# 42272        Rising and falling between a man and woman.    0.072051
# 42273  An artist struggles to finish his work while a...    0.178241
# 42274  In a small town live two brothers, one a minis...    0.003503
# 42275  50 years after decriminalisation of homosexual...    0.163015
#
#                             poster_path  \
# 0      /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1      /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 2      /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# 3      /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# 4      /e64sOI48hQXyru7naBFyssKFxVd.jpg
# ...                                 ...
# 42271  /4lF9LH0b0Z1X94xGK9IOzqEW6k1.jpg
# 42272  /jldsYflnId4tTWPx8es3uzsB1I8.jpg
# 42273  /xZkmxsNmYXJbKVsTRLLx3pqGHx7.jpg
# 42274  /aorBPO7ak8e8iJKT5OcqYxU3jlK.jpg
# 42275  /s5UkZt6NTsrS7ZF0Rh8nzupRlIU.jpg
#
#                                     production_companies  \
# 0                             (Pixar Animation Studios,)
# 1      (Interscope Communications, Teitler Film, TriS...
# 2                         (Lancaster Gate, Warner Bros.)
# 3              (Twentieth Century Fox Film Corporation,)
# 4           (Sandollar Productions, Touchstone Pictures)
# ...                                                  ...
# 42271                           (Concorde-New Horizons,)
# 42272                                                 ()
# 42273                                     (Sine Olivia,)
# 42274                                       (Yermoliev,)
# 42275                                                 ()
#
#               production_countries release_date      revenue  runtime  \
# 0      (United States of America,)   1995-10-30  373554033.0     81.0
# 1      (United States of America,)   1995-12-15  262797249.0    104.0
# 2      (United States of America,)   1995-12-22          0.0    101.0
# 3      (United States of America,)   1995-12-22   81452156.0    127.0
# 4      (United States of America,)   1995-02-10   76578911.0    106.0
# ...                            ...          ...          ...      ...
# 42271  (United States of America,)   1995-01-01          0.0     85.0
# 42272                      (Iran,)          NaT          0.0     90.0
# 42273               (Philippines,)   2011-11-17          0.0    360.0
# 42274                    (Russia,)   1917-10-21          0.0     87.0
# 42275            (United Kingdom,)   2017-06-09          0.0     75.0
#
#           spoken_languages    status  \
# 0               (English,)  Released
# 1      (English, Français)  Released
# 2               (English,)  Released
# 3               (English,)  Released
# 4               (English,)  Released
# ...                    ...       ...
# 42271           (English,)  Released
# 42272             (فارسی,)  Released
# 42273                  (,)  Released
# 42274                   ()  Released
# 42275           (English,)  Released
#
#                                                  tagline  \
# 0                                                    NaN
# 1              Roll the dice and unleash the excitement!
# 2      Still Yelling. Still Fighting. Still Ready for...
# 3      Friends are the people who let you be yourself...
# 4      Just When His World Is Back To Normal... He's ...
# ...                                                  ...
# 42271                                                NaN
# 42272         Rising and falling between a man and woman
# 42273                                                NaN
# 42274                                                NaN
# 42275                                                NaN
#
#                              title  video  vote_average  vote_count  \
# 0                        Toy Story  False           7.7        5415
# 1                          Jumanji  False           6.9        2413
# 2                 Grumpier Old Men  False           6.5          92
# 3                Waiting to Exhale  False           6.1          34
# 4      Father of the Bride Part II  False           5.7         173
# ...                            ...    ...           ...         ...
# 42271              Caged Heat 3000  False           3.5           1
# 42272                       Subdue  False           4.0           1
# 42273          Century of Birthing  False           9.0           3
# 42274             Satan Triumphant  False           0.0           0
# 42275                     Queerama  False           0.0           0
#
#                                                     cast  \
# 0      (Annie Potts, Don Rickles, Erik von Detten, Ji...
# 1      (Adam Hann-Byrd, Annabel Kershaw, Bebe Neuwirt...
# 2      (Ann-Margret, Burgess Meredith, Daryl Hannah, ...
# 3      (Angela Bassett, Dennis Haysbert, Gregory Hine...
# 4      (BD Wong, Diane Keaton, Eugene Levy, George Ne...
# ...                                                  ...
# 42271  (Ben Ramsey, Debra K. Beatty, Don Yanan, Ellyn...
# 42272        (Elham Korda, Kourosh Tahami, Leila Hatami)
# 42273  (Angel Aquino, Angeli Bayani, Bart Guingona, B...
# 42274  (Aleksandr Chabrov, Iwan Mosschuchin, Nathalie...
# 42275                                                 ()
#
#                                                     crew  \
# 0      (Ada Cochavi, Alan Sperling, Alec Sokolow, And...
# 1      (Chris van Allsburg, Greg Taylor, James D. Bis...
# 2      (Howard Deutch, Jack Keller, Mark Steven Johns...
# 3      (Caron K, Deborah Schindler, Ezra Swerdlow, Fo...
# 4      (Adam Bernardi, Alan Silvestri, Albert Hackett...
# ...                                                  ...
# 42271  (Aaron Osborne, Emile Dupont, Felix Chamberlai...
# 42272  (Azadeh Ghavam, Babak Ardalan, Farshad Mohamma...
# 42273  (Dante Perez, Lav Diaz, Lav Diaz, Lav Diaz, La...
# 42274            (Joseph N. Ermolieff, Yakov Protazanov)
# 42275                                   (Daisy Asquith,)
#
#                                                 keywords
# 0      (boy, boy next door, friends, friendship, jeal...
# 1      (based on children's book, board game, disappe...
# 2      (best friend, duringcreditsstinger, fishing, o...
# 3      (based on novel, chick flick, divorce, interra...
# 4      (aging, baby, confidence, contraception, daugh...
# ...                                                  ...
# 42271                                                 ()
# 42272                                     (tragic love,)
# 42273                              (artist, pinoy, play)
# 42274                                                 ()
# 42275                                                 ()
#
# [42276 rows x 27 columns]

# %%
main = everything.drop([
    'adult', # there's only 9 adult films
    'budget', # might be useful for decision trees
    'homepage', 
    'imdb_id', 
    'poster_path',
    'revenue', # might be useful for decision trees
    'original_title', # its in the original language, 'title' is in english
    'video', # there's only 95 non video movies
], axis=1)
main = main[[
    'id', 
    'title', 
    'overview', 
    'genres',
    'belongs_to_collection',
    'original_language',
    'popularity',
    'production_companies',
    'production_countries', 
    'release_date', 
    'runtime', 
    'spoken_languages',
    'status', 
    'tagline', 
    'vote_average', 
    'vote_count', 
    'cast',
    'crew', 
    'keywords'
]]
main
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 42271  222848              Caged Heat 3000
# 42272  439050                       Subdue
# 42273  111109          Century of Birthing
# 42274  227506             Satan Triumphant
# 42275  461257                     Queerama
#
#                                                 overview  \
# 0      Led by Woody, Andy's toys live happily in his ...
# 1      When siblings Judy and Peter discover an encha...
# 2      A family wedding reignites the ancient feud be...
# 3      Cheated on, mistreated and stepped on, the wom...
# 4      Just when George Banks has recovered from his ...
# ...                                                  ...
# 42271  It's the year 3000 AD. The world's most danger...
# 42272        Rising and falling between a man and woman.
# 42273  An artist struggles to finish his work while a...
# 42274  In a small town live two brothers, one a minis...
# 42275  50 years after decriminalisation of homosexual...
#
#                              genres           belongs_to_collection  \
# 0       (Animation, Comedy, Family)            Toy Story Collection
# 1      (Adventure, Family, Fantasy)
# 2                 (Comedy, Romance)       Grumpy Old Men Collection
# 3          (Comedy, Drama, Romance)
# 4                         (Comedy,)  Father of the Bride Collection
# ...                             ...                             ...
# 42271            (Science Fiction,)
# 42272               (Drama, Family)
# 42273                      (Drama,)
# 42274                            ()
# 42275                            ()
#
#       original_language  popularity  \
# 0                    en   21.946943
# 1                    en   17.015539
# 2                    en   11.712900
# 3                    en    3.859495
# 4                    en    8.387519
# ...                 ...         ...
# 42271                en    0.661558
# 42272                fa    0.072051
# 42273                tl    0.178241
# 42274                en    0.003503
# 42275                en    0.163015
#
#                                     production_companies  \
# 0                             (Pixar Animation Studios,)
# 1      (Interscope Communications, Teitler Film, TriS...
# 2                         (Lancaster Gate, Warner Bros.)
# 3              (Twentieth Century Fox Film Corporation,)
# 4           (Sandollar Productions, Touchstone Pictures)
# ...                                                  ...
# 42271                           (Concorde-New Horizons,)
# 42272                                                 ()
# 42273                                     (Sine Olivia,)
# 42274                                       (Yermoliev,)
# 42275                                                 ()
#
#               production_countries release_date  runtime     spoken_languages  \
# 0      (United States of America,)   1995-10-30     81.0           (English,)
# 1      (United States of America,)   1995-12-15    104.0  (English, Français)
# 2      (United States of America,)   1995-12-22    101.0           (English,)
# 3      (United States of America,)   1995-12-22    127.0           (English,)
# 4      (United States of America,)   1995-02-10    106.0           (English,)
# ...                            ...          ...      ...                  ...
# 42271  (United States of America,)   1995-01-01     85.0           (English,)
# 42272                      (Iran,)          NaT     90.0             (فارسی,)
# 42273               (Philippines,)   2011-11-17    360.0                  (,)
# 42274                    (Russia,)   1917-10-21     87.0                   ()
# 42275            (United Kingdom,)   2017-06-09     75.0           (English,)
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 42271  Released                                                NaN
# 42272  Released         Rising and falling between a man and woman
# 42273  Released                                                NaN
# 42274  Released                                                NaN
# 42275  Released                                                NaN
#
#        vote_average  vote_count  \
# 0               7.7        5415
# 1               6.9        2413
# 2               6.5          92
# 3               6.1          34
# 4               5.7         173
# ...             ...         ...
# 42271           3.5           1
# 42272           4.0           1
# 42273           9.0           3
# 42274           0.0           0
# 42275           0.0           0
#
#                                                     cast  \
# 0      (Annie Potts, Don Rickles, Erik von Detten, Ji...
# 1      (Adam Hann-Byrd, Annabel Kershaw, Bebe Neuwirt...
# 2      (Ann-Margret, Burgess Meredith, Daryl Hannah, ...
# 3      (Angela Bassett, Dennis Haysbert, Gregory Hine...
# 4      (BD Wong, Diane Keaton, Eugene Levy, George Ne...
# ...                                                  ...
# 42271  (Ben Ramsey, Debra K. Beatty, Don Yanan, Ellyn...
# 42272        (Elham Korda, Kourosh Tahami, Leila Hatami)
# 42273  (Angel Aquino, Angeli Bayani, Bart Guingona, B...
# 42274  (Aleksandr Chabrov, Iwan Mosschuchin, Nathalie...
# 42275                                                 ()
#
#                                                     crew  \
# 0      (Ada Cochavi, Alan Sperling, Alec Sokolow, And...
# 1      (Chris van Allsburg, Greg Taylor, James D. Bis...
# 2      (Howard Deutch, Jack Keller, Mark Steven Johns...
# 3      (Caron K, Deborah Schindler, Ezra Swerdlow, Fo...
# 4      (Adam Bernardi, Alan Silvestri, Albert Hackett...
# ...                                                  ...
# 42271  (Aaron Osborne, Emile Dupont, Felix Chamberlai...
# 42272  (Azadeh Ghavam, Babak Ardalan, Farshad Mohamma...
# 42273  (Dante Perez, Lav Diaz, Lav Diaz, Lav Diaz, La...
# 42274            (Joseph N. Ermolieff, Yakov Protazanov)
# 42275                                   (Daisy Asquith,)
#
#                                                 keywords
# 0      (boy, boy next door, friends, friendship, jeal...
# 1      (based on children's book, board game, disappe...
# 2      (best friend, duringcreditsstinger, fishing, o...
# 3      (based on novel, chick flick, divorce, interra...
# 4      (aging, baby, confidence, contraception, daugh...
# ...                                                  ...
# 42271                                                 ()
# 42272                                     (tragic love,)
# 42273                              (artist, pinoy, play)
# 42274                                                 ()
# 42275                                                 ()
#
# [42276 rows x 19 columns]

# %%
from collections import defaultdict

def analyse_array_column(column):
    counter = defaultdict(int)
    for array in main[column]:
        for item in array:
            counter[item] += 1
    print('=' * 20, column,'=' * 20)
    print('Unique Items', len(counter))
    items = sorted(counter.items(), key=lambda x: x[1], reverse=True)
    pprint(items[:20])
    print('...' if len(items) > 20 else '')

# %%
analyse_array_column('genres')
analyse_array_column('production_companies')
analyse_array_column('production_countries')
analyse_array_column('spoken_languages')
analyse_array_column('cast')
analyse_array_column('crew')
analyse_array_column('keywords')
# Out:
# ==================== genres ====================
# Unique Items 20
# [('Drama', 18625),
#  ('Comedy', 12553),
#  ('Thriller', 6869),
#  ('Romance', 6229),
#  ('Action', 6126),
#  ('Horror', 4223),
#  ('Crime', 3959),
#  ('Documentary', 3794),
#  ('Adventure', 3235),
#  ('Science Fiction', 2834),
#  ('Family', 2594),
#  ('Mystery', 2269),
#  ('Fantasy', 2124),
#  ('Animation', 1847),
#  ('Music', 1517),
#  ('Foreign', 1502),
#  ('History', 1308),
#  ('War', 1242),
#  ('Western', 984),
#  ('TV Movie', 676)]
#
# ==================== production_companies ====================
# Unique Items 22381
# [('Warner Bros.', 1191),
#  ('Metro-Goldwyn-Mayer (MGM)', 991),
#  ('Paramount Pictures', 930),
#  ('Universal Pictures', 789),
#  ('Twentieth Century Fox Film Corporation', 775),
#  ('Columbia Pictures Corporation', 425),
#  ('Columbia Pictures', 406),
#  ('Canal+', 399),
#  ('RKO Radio Pictures', 269),
#  ('United Artists', 268),
#  ('New Line Cinema', 266),
#  ('Walt Disney Pictures', 237),
#  ('Touchstone Pictures', 212),
#  ('TriStar Pictures', 195),
#  ('Miramax Films', 174),
#  ('Mosfilm', 169),
#  ('France 2 Cinéma', 154),
#  ('Centre National de la Cinématographie (CNC)', 151),
#  ('Toho Company', 135),
#  ('BBC Films', 119)]
# ...
# ==================== production_countries ====================
# Unique Items 159
# [('United States of America', 19766),
#  ('United Kingdom', 3742),
#  ('France', 3620),
#  ('Germany', 2084),
#  ('Italy', 2021),
#  ('Canada', 1639),
#  ('Japan', 1570),
#  ('Spain', 898),
#  ('Russia', 801),
#  ('India', 790),
#  ('Hong Kong', 551),
#  ('Sweden', 543),
#  ('Australia', 518),
#  ('South Korea', 439),
#  ('Belgium', 400),
#  ('Finland', 359),
#  ('Denmark', 358),
#  ('Netherlands', 342),
#  ('China', 335),
#  ('Mexico', 306)]
# ...
# ==================== spoken_languages ====================
# Unique Items 75
# [('English', 26812),
#  ('Français', 3880),
#  ('Deutsch', 2456),
#  ('Español', 2259),
#  ('Italiano', 2228),
#  ('日本語', 1688),
#  ('Pусский', 1415),
#  ('普通话', 734),
#  ('हिन्दी', 673),
#  ('Português', 549),
#  ('svenska', 518),
#  ('한국어/조선말', 483),
#  ('Polski', 481),
#  ('', 469),
#  ('广州话 / 廣州話', 437),
#  ('suomi', 347),
#  ('Magyar', 334),
#  ('العربية', 315),
#  ('Nederlands', 305),
#  ('No Language', 289)]
# ...
# ==================== cast ====================
# Unique Items 192623
# [('Bess Flowers', 221),
#  ('Christopher Lee', 139),
#  ('John Wayne', 122),
#  ('Samuel L. Jackson', 116),
#  ('Frank Welker', 105),
#  ('Jackie Chan', 105),
#  ('Donald Sutherland', 103),
#  ('Gérard Depardieu', 103),
#  ('John Carradine', 103),
#  ('Michael Caine', 100),
#  ('Steve Buscemi', 97),
#  ('Robert De Niro', 96),
#  ('Danny Trejo', 95),
#  ('John Goodman', 93),
#  ('Irving Bacon', 93),
#  ('Danny Glover', 90),
#  ('Susan Sarandon', 88),
#  ('Harvey Keitel', 88),
#  ('Bruce Willis', 86),
#  ('Dennis Hopper', 86)]
# ...
# ==================== crew ====================
# Unique Items 149994
# [('Cedric Gibbons', 245),
#  ('Avy Kaufman', 171),
#  ('Edith Head', 153),
#  ('Roger Corman', 149),
#  ('Max Steiner', 146),
#  ('Ennio Morricone', 140),
#  ('Kerry Barden', 138),
#  ('Charlie Chaplin', 132),
#  ('Jerry Goldsmith', 131),
#  ('Mel Berns', 130),
#  ('Mary Vernieu', 129),
#  ('Hal B. Wallis', 126),
#  ('Billy Hopkins', 124),
#  ('Lynn Stalmaster', 122),
#  ('Steven Spielberg', 119),
#  ('Deborah Aquila', 119),
#  ('Werner Herzog', 119),
#  ('Darryl F. Zanuck', 116),
#  ('Suzanne Smith', 114),
#  ('Robert Rodriguez', 113)]
# ...
# ==================== keywords ====================
# Unique Items 19445
# [('woman director', 2826),
#  ('independent film', 1824),
#  ('murder', 1165),
#  ('based on novel', 733),
#  ('musical', 676),
#  ('sex', 642),
#  ('violence', 590),
#  ('nudity', 583),
#  ('biography', 576),
#  ('revenge', 564),
#  ('suspense', 542),
#  ('female nudity', 528),
#  ('love', 519),
#  ('sport', 512),
#  ('sequel', 425),
#  ('police', 421),
#  ('duringcreditsstinger', 413),
#  ('teenager', 407),
#  ('friendship', 383),
#  ('world war ii', 370)]
# ...

# %%
main.to_csv('./data/basic.csv')

# %%
main
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 42271  222848              Caged Heat 3000
# 42272  439050                       Subdue
# 42273  111109          Century of Birthing
# 42274  227506             Satan Triumphant
# 42275  461257                     Queerama
#
#                                                 overview  \
# 0      Led by Woody, Andy's toys live happily in his ...
# 1      When siblings Judy and Peter discover an encha...
# 2      A family wedding reignites the ancient feud be...
# 3      Cheated on, mistreated and stepped on, the wom...
# 4      Just when George Banks has recovered from his ...
# ...                                                  ...
# 42271  It's the year 3000 AD. The world's most danger...
# 42272        Rising and falling between a man and woman.
# 42273  An artist struggles to finish his work while a...
# 42274  In a small town live two brothers, one a minis...
# 42275  50 years after decriminalisation of homosexual...
#
#                              genres           belongs_to_collection  \
# 0       (Animation, Comedy, Family)            Toy Story Collection
# 1      (Adventure, Family, Fantasy)
# 2                 (Comedy, Romance)       Grumpy Old Men Collection
# 3          (Comedy, Drama, Romance)
# 4                         (Comedy,)  Father of the Bride Collection
# ...                             ...                             ...
# 42271            (Science Fiction,)
# 42272               (Drama, Family)
# 42273                      (Drama,)
# 42274                            ()
# 42275                            ()
#
#       original_language  popularity  \
# 0                    en   21.946943
# 1                    en   17.015539
# 2                    en   11.712900
# 3                    en    3.859495
# 4                    en    8.387519
# ...                 ...         ...
# 42271                en    0.661558
# 42272                fa    0.072051
# 42273                tl    0.178241
# 42274                en    0.003503
# 42275                en    0.163015
#
#                                     production_companies  \
# 0                             (Pixar Animation Studios,)
# 1      (Interscope Communications, Teitler Film, TriS...
# 2                         (Lancaster Gate, Warner Bros.)
# 3              (Twentieth Century Fox Film Corporation,)
# 4           (Sandollar Productions, Touchstone Pictures)
# ...                                                  ...
# 42271                           (Concorde-New Horizons,)
# 42272                                                 ()
# 42273                                     (Sine Olivia,)
# 42274                                       (Yermoliev,)
# 42275                                                 ()
#
#               production_countries release_date  runtime     spoken_languages  \
# 0      (United States of America,)   1995-10-30     81.0           (English,)
# 1      (United States of America,)   1995-12-15    104.0  (English, Français)
# 2      (United States of America,)   1995-12-22    101.0           (English,)
# 3      (United States of America,)   1995-12-22    127.0           (English,)
# 4      (United States of America,)   1995-02-10    106.0           (English,)
# ...                            ...          ...      ...                  ...
# 42271  (United States of America,)   1995-01-01     85.0           (English,)
# 42272                      (Iran,)          NaT     90.0             (فارسی,)
# 42273               (Philippines,)   2011-11-17    360.0                  (,)
# 42274                    (Russia,)   1917-10-21     87.0                   ()
# 42275            (United Kingdom,)   2017-06-09     75.0           (English,)
#
#          status                                            tagline  \
# 0      Released                                                NaN
# 1      Released          Roll the dice and unleash the excitement!
# 2      Released  Still Yelling. Still Fighting. Still Ready for...
# 3      Released  Friends are the people who let you be yourself...
# 4      Released  Just When His World Is Back To Normal... He's ...
# ...         ...                                                ...
# 42271  Released                                                NaN
# 42272  Released         Rising and falling between a man and woman
# 42273  Released                                                NaN
# 42274  Released                                                NaN
# 42275  Released                                                NaN
#
#        vote_average  vote_count  \
# 0               7.7        5415
# 1               6.9        2413
# 2               6.5          92
# 3               6.1          34
# 4               5.7         173
# ...             ...         ...
# 42271           3.5           1
# 42272           4.0           1
# 42273           9.0           3
# 42274           0.0           0
# 42275           0.0           0
#
#                                                     cast  \
# 0      (Annie Potts, Don Rickles, Erik von Detten, Ji...
# 1      (Adam Hann-Byrd, Annabel Kershaw, Bebe Neuwirt...
# 2      (Ann-Margret, Burgess Meredith, Daryl Hannah, ...
# 3      (Angela Bassett, Dennis Haysbert, Gregory Hine...
# 4      (BD Wong, Diane Keaton, Eugene Levy, George Ne...
# ...                                                  ...
# 42271  (Ben Ramsey, Debra K. Beatty, Don Yanan, Ellyn...
# 42272        (Elham Korda, Kourosh Tahami, Leila Hatami)
# 42273  (Angel Aquino, Angeli Bayani, Bart Guingona, B...
# 42274  (Aleksandr Chabrov, Iwan Mosschuchin, Nathalie...
# 42275                                                 ()
#
#                                                     crew  \
# 0      (Ada Cochavi, Alan Sperling, Alec Sokolow, And...
# 1      (Chris van Allsburg, Greg Taylor, James D. Bis...
# 2      (Howard Deutch, Jack Keller, Mark Steven Johns...
# 3      (Caron K, Deborah Schindler, Ezra Swerdlow, Fo...
# 4      (Adam Bernardi, Alan Silvestri, Albert Hackett...
# ...                                                  ...
# 42271  (Aaron Osborne, Emile Dupont, Felix Chamberlai...
# 42272  (Azadeh Ghavam, Babak Ardalan, Farshad Mohamma...
# 42273  (Dante Perez, Lav Diaz, Lav Diaz, Lav Diaz, La...
# 42274            (Joseph N. Ermolieff, Yakov Protazanov)
# 42275                                   (Daisy Asquith,)
#
#                                                 keywords
# 0      (boy, boy next door, friends, friendship, jeal...
# 1      (based on children's book, board game, disappe...
# 2      (best friend, duringcreditsstinger, fishing, o...
# 3      (based on novel, chick flick, divorce, interra...
# 4      (aging, baby, confidence, contraception, daugh...
# ...                                                  ...
# 42271                                                 ()
# 42272                                     (tragic love,)
# 42273                              (artist, pinoy, play)
# 42274                                                 ()
# 42275                                                 ()
#
# [42276 rows x 19 columns]

# %%
movies_unique.to_csv('data/metadata.csv')
